# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from __future__ import print_function, division

import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import numpy as np
import time
import copy

# %%
# Directory with our validation dandelion pictures
train_dir = os.path.join('/content/gdrive/MyDrive/GTVD-(DS440-Team1)/Data/Data_collection1/Benchmark_training') 

# Directory with our validation grass pictures
valid_dir = os.path.join('/content/gdrive/MyDrive/GTVD-(DS440-Team1)/Data/Data_collection1/Benchmark_validation')

# %%
# Make transforms and use data loaders
# make these variables for future use

mean_nums = [0.485, 0.456, 0.406]
std_nums = [0.229, 0.224, 0.225]

chosen_transforms = {'Benchmark_training': transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean_nums, std_nums)
]), 'Benchmark_validation': transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean_nums, std_nums)
]),
}

# %%
# set the directory for the data
data_dir = os.path.join('/content/gdrive/MyDrive/GTVD-(DS440-Team1)/Data/Data_collection1') 

chosen_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
  chosen_transforms[x])
                  for x in ['Benchmark_training', 'Benchmark_validation']}

# %%
# Make iterables with the dataloaders
dataloaders = {x: torch.utils.data.DataLoader(chosen_datasets[x], batch_size=4,
  shuffle=True, num_workers=2)
              for x in ['Benchmark_training', 'Benchmark_validation']}

# %%
dataset_sizes = {x: len(chosen_datasets[x]) for x in ['Benchmark_training', 'Benchmark_validation']}
class_names = chosen_datasets['Benchmark_training'].classes

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
dataset_sizes
# Out:
# {'Benchmark_training': 678, 'Benchmark_validation': 142}

# %%
class_names
# Out:
# ['Non_Violation', 'Violation']

# %% [markdown]
# imshow for tensor: https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([mean_nums])
    std = np.array([std_nums])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated

# %%
# visualiza some training data to get a sense of data augmentations
inputs, classes = next(iter(dataloaders["Benchmark_training"]))
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
# Setting up the model
vgg_mod = models.vgg16(pretrained=True)

num_ftrs = vgg_mod.classifier[6].in_features
features = list(vgg_mod.classifier.children())[:-1] # Remove last layer
features.extend([nn.Linear(num_ftrs, 2)]) # Add our layer with 2 outputs
vgg_mod.classifier = nn.Sequential(*features)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
vgg_mod = vgg_mod.to(device)
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(vgg_mod.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %% [markdown]
# A general function to train a model, this function will illustrate:
# - scheduling the learning rate
# - saving the best model
#
#
# parameter scheduler is an LR scheduler object from torch.optim.lr_scheduler.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=10):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['Benchmark_training', 'Benchmark_validation']:
            if phase == 'Benchmark_training':
                # scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            current_loss = 0.0
            current_corrects = 0

            # Here's where the training happens
            print('Iterating through data...')

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # We need to zero the gradients
                optimizer.zero_grad()

                # Time to carry out the forward training poss
                # We only need to log the loss stats if we are in training phase
                with torch.set_grad_enabled(phase == 'Benchmark_training'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'Benchmark_training':
                        loss.backward()
                        optimizer.step()

                # We want variables to hold the loss statistics
                current_loss += loss.item() * inputs.size(0)
                current_corrects += torch.sum(preds == labels.data)

            if phase == 'Benchmark_training':
                scheduler.step()

            epoch_loss = current_loss / dataset_sizes[phase]
            epoch_acc = current_corrects.double() / dataset_sizes[phase]

            # collect accuracy for future use
            if phase == 'Benchmark_training':
              train_acc.append(epoch_acc)
            else:
              val_acc.append(epoch_acc)
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # Make a copy of the model if the accuracy on the validation set has improved
            if phase == 'Benchmark_validation' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_since = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_since // 60, time_since % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # Now we'll load in the best model weights and return it
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_handeled = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['Benchmark_validation']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_handeled += 1
                ax = plt.subplot(num_images//2, 2, images_handeled)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_handeled == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
train_acc=[]
val_acc=[]
base_model = train_model(vgg_mod, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=25)
visualize_model(base_model)
plt.show()
# Out:
# Epoch 0/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.7218 Acc: 0.5546
# Iterating through data...
# Benchmark_validation Loss: 0.5370 Acc: 0.7113
#
# Epoch 1/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.6173 Acc: 0.6740
# Iterating through data...
# Benchmark_validation Loss: 0.5649 Acc: 0.7746
#
# Epoch 2/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.4916 Acc: 0.7655
# Iterating through data...
# Benchmark_validation Loss: 0.5167 Acc: 0.7606
#
# Epoch 3/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.4677 Acc: 0.7861
# Iterating through data...
# Benchmark_validation Loss: 0.5377 Acc: 0.7535
#
# Epoch 4/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.3700 Acc: 0.8466
# Iterating through data...
# Benchmark_validation Loss: 0.5746 Acc: 0.7535
#
# Epoch 5/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.3433 Acc: 0.8525
# Iterating through data...
# Benchmark_validation Loss: 0.8559 Acc: 0.5000
#
# Epoch 6/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.4028 Acc: 0.8068
# Iterating through data...
# Benchmark_validation Loss: 0.4685 Acc: 0.8028
#
# Epoch 7/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2419 Acc: 0.8968
# Iterating through data...
# Benchmark_validation Loss: 0.4646 Acc: 0.8521
#
# Epoch 8/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2349 Acc: 0.8982
# Iterating through data...
# Benchmark_validation Loss: 0.4898 Acc: 0.8592
#
# Epoch 9/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1971 Acc: 0.9145
# Iterating through data...
# Benchmark_validation Loss: 0.4531 Acc: 0.8592
#
# Epoch 10/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1949 Acc: 0.9248
# Iterating through data...
# Benchmark_validation Loss: 0.5079 Acc: 0.8521
#
# Epoch 11/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1779 Acc: 0.9248
# Iterating through data...
# Benchmark_validation Loss: 0.5270 Acc: 0.8380
#
# Epoch 12/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1886 Acc: 0.9218
# Iterating through data...
# Benchmark_validation Loss: 0.4654 Acc: 0.8521
#
# Epoch 13/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1748 Acc: 0.9366
# Iterating through data...
# Benchmark_validation Loss: 0.4935 Acc: 0.8310
#
# Epoch 14/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1436 Acc: 0.9395
# Iterating through data...
# Benchmark_validation Loss: 0.4418 Acc: 0.8662
#
# Epoch 15/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1738 Acc: 0.9263
# Iterating through data...
# Benchmark_validation Loss: 0.4476 Acc: 0.8592
#
# Epoch 16/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1909 Acc: 0.9115
# Iterating through data...
# Benchmark_validation Loss: 0.4622 Acc: 0.8451
#
# Epoch 17/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1502 Acc: 0.9307
# Iterating through data...
# Benchmark_validation Loss: 0.4378 Acc: 0.8732
#
# Epoch 18/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1312 Acc: 0.9528
# Iterating through data...
# Benchmark_validation Loss: 0.4545 Acc: 0.8592
#
# Epoch 19/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1183 Acc: 0.9543
# Iterating through data...
# Benchmark_validation Loss: 0.4460 Acc: 0.8592
#
# Epoch 20/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1323 Acc: 0.9558
# Iterating through data...
# Benchmark_validation Loss: 0.4614 Acc: 0.8521
#
# Epoch 21/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1484 Acc: 0.9351
# Iterating through data...
# Benchmark_validation Loss: 0.4606 Acc: 0.8521
#
# Epoch 22/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1386 Acc: 0.9381
# Iterating through data...
# Benchmark_validation Loss: 0.4582 Acc: 0.8592
#
# Epoch 23/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1463 Acc: 0.9440
# Iterating through data...
# Benchmark_validation Loss: 0.4531 Acc: 0.8592
#
# Epoch 24/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.1391 Acc: 0.9410
# Iterating through data...
# Benchmark_validation Loss: 0.4558 Acc: 0.8592
#
# Training complete in 23m 24s
# Best val Acc: 0.873239

# %%
tacc = torch.stack(train_acc)
tacc = tacc.cpu().detach().numpy()
vacc = torch.stack(val_acc)
vacc = vacc.cpu().detach().numpy()

# %%
# accuracy plot
fig = plt.figure(figsize=(10,7))
plt.title("Train-Validation Accuracy")
plt.plot(tacc, label='train')
plt.plot(vacc, label='validation')
plt.xlabel('num_epochs', fontsize=12)
plt.ylabel('accuracy', fontsize=12)
plt.legend(loc='best')

# %% [markdown]
# use the test dataset to see the performance

# %%
predlist = torch.zeros(0, dtype=torch.long, device='cpu')
lbllist = torch.zeros(0, dtype=torch.long, device = 'cpu')

with torch.no_grad():
  for inputs, classes in dataloaders['Benchmark_validation']:
    inputs = inputs.to(device)
    classes = classes.to(device)
    outputs = base_model(inputs)
    _, preds = torch.max(outputs, 1)

    predlist=torch.cat([predlist, preds.view(-1).cpu()])
    lbllist=torch.cat([lbllist, classes.view(-1).cpu()])

  preds = predlist.numpy()
  labels = lbllist.numpy()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
conf_mat = confusion_matrix(labels, preds)
fig, ax = plt.subplots(figsize = (8,8))
sns.heatmap(conf_mat, annot = True, fmt = 'd')
plt.ylabel('Actual')
plt.xlabel('pred')
plt.show()

# %%
cm=confusion_matrix(labels,preds)
print(cm)
# Out:
# [[40  5]
#  [11 86]]

# %%
from sklearn.metrics import classification_report
matrix = classification_report(labels,preds,target_names=class_names)
print('Classification report : \n',matrix)
# Out:
# Classification report :
#                 precision    recall  f1-score   support
#
# Non_Violation       0.78      0.89      0.83        45
#     Violation       0.95      0.89      0.91        97
#
#      accuracy                           0.89       142
#     macro avg       0.86      0.89      0.87       142
#  weighted avg       0.89      0.89      0.89       142
