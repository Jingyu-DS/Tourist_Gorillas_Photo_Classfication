# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from __future__ import print_function, division

import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import numpy as np
import time
import copy

# %%
# Directory with our validation dandelion pictures
train_dir = os.path.join('/content/gdrive/MyDrive/GTVD-(DS440-Team1)/Data/Data_collection1/Benchmark_training') 

# Directory with our validation grass pictures
valid_dir = os.path.join('/content/gdrive/MyDrive/GTVD-(DS440-Team1)/Data/Data_collection1/Benchmark_validation')

# %%
# Make transforms and use data loaders
# make these variables for future use

mean_nums = [0.485, 0.456, 0.406]
std_nums = [0.229, 0.224, 0.225]

chosen_transforms = {'Benchmark_training': transforms.Compose([
        transforms.RandomResizedCrop(size=256),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean_nums, std_nums)
]), 'Benchmark_validation': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean_nums, std_nums)
]),
}

# %%
# set the directory for the data
data_dir = os.path.join('/content/gdrive/MyDrive/GTVD-(DS440-Team1)/Data/Data_collection1') 

chosen_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
  chosen_transforms[x])
                  for x in ['Benchmark_training', 'Benchmark_validation']}

# %%
# Make iterables with the dataloaders
dataloaders = {x: torch.utils.data.DataLoader(chosen_datasets[x], batch_size=4,
  shuffle=True, num_workers=2)
              for x in ['Benchmark_training', 'Benchmark_validation']}

# %%
dataset_sizes = {x: len(chosen_datasets[x]) for x in ['Benchmark_training', 'Benchmark_validation']}
class_names = chosen_datasets['Benchmark_training'].classes

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
dataset_sizes
# Out:
# {'Benchmark_training': 678, 'Benchmark_validation': 142}

# %% [markdown]
# imshow for tensor: https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([mean_nums])
    std = np.array([std_nums])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated

# %%
# visualiza some training data to get a sense of data augmentations
inputs, classes = next(iter(dataloaders["Benchmark_training"]))
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
# Setting up the model
# load in pretrained and reset final fully connected

res_mod = models.resnet50(pretrained=True)

num_ftrs = res_mod.fc.in_features
res_mod.fc = nn.Linear(num_ftrs, 2)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
res_mod = res_mod.to(device)
criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(res_mod.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %% [markdown]
# A general function to train a model, this function will illustrate:
# - scheduling the learning rate
# - saving the best model
#
#
# parameter scheduler is an LR scheduler object from torch.optim.lr_scheduler.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=10):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['Benchmark_training', 'Benchmark_validation']:
            if phase == 'Benchmark_training':
                # scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            current_loss = 0.0
            current_corrects = 0

            # Here's where the training happens
            print('Iterating through data...')

            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # We need to zero the gradients
                optimizer.zero_grad()

                # Time to carry out the forward training poss
                # We only need to log the loss stats if we are in training phase
                with torch.set_grad_enabled(phase == 'Benchmark_training'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'Benchmark_training':
                        loss.backward()
                        optimizer.step()

                # We want variables to hold the loss statistics
                current_loss += loss.item() * inputs.size(0)
                current_corrects += torch.sum(preds == labels.data)

            if phase == 'Benchmark_training':
                scheduler.step()

            epoch_loss = current_loss / dataset_sizes[phase]
            epoch_acc = current_corrects.double() / dataset_sizes[phase]

            # collect accuracy for future use
            if phase == 'Benchmark_training':
              train_acc.append(epoch_acc)
              train_loss.append(epoch_loss)
            else:
              val_acc.append(epoch_acc)
              val_loss.append(epoch_loss)
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # Make a copy of the model if the accuracy on the validation set has improved
            if phase == 'Benchmark_validation' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_since = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_since // 60, time_since % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # Now we'll load in the best model weights and return it
    model.load_state_dict(best_model_wts)
    return model

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_handeled = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['Benchmark_validation']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_handeled += 1
                ax = plt.subplot(num_images//2, 2, images_handeled)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_handeled == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
train_acc=[]
val_acc=[]
train_loss=[]
val_loss=[]
base_model = train_model(res_mod, criterion, optimizer_ft, exp_lr_scheduler, num_epochs=25)
visualize_model(base_model)
plt.show()
# Out:
# Epoch 0/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.5129 Acc: 0.8024
# Iterating through data...
# Benchmark_validation Loss: 0.3364 Acc: 0.8169
#
# Epoch 1/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.4575 Acc: 0.8260
# Iterating through data...
# Benchmark_validation Loss: 0.4113 Acc: 0.8803
#
# Epoch 2/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.3255 Acc: 0.8658
# Iterating through data...
# Benchmark_validation Loss: 0.4319 Acc: 0.8099
#
# Epoch 3/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.3729 Acc: 0.8658
# Iterating through data...
# Benchmark_validation Loss: 0.2775 Acc: 0.8944
#
# Epoch 4/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.3532 Acc: 0.8673
# Iterating through data...
# Benchmark_validation Loss: 0.3233 Acc: 0.9014
#
# Epoch 5/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2680 Acc: 0.9159
# Iterating through data...
# Benchmark_validation Loss: 0.3775 Acc: 0.8944
#
# Epoch 6/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2495 Acc: 0.9027
# Iterating through data...
# Benchmark_validation Loss: 0.2237 Acc: 0.9155
#
# Epoch 7/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2192 Acc: 0.9159
# Iterating through data...
# Benchmark_validation Loss: 0.2965 Acc: 0.8732
#
# Epoch 8/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2358 Acc: 0.9056
# Iterating through data...
# Benchmark_validation Loss: 0.4901 Acc: 0.8380
#
# Epoch 9/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2629 Acc: 0.8923
# Iterating through data...
# Benchmark_validation Loss: 0.2628 Acc: 0.8944
#
# Epoch 10/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2465 Acc: 0.8997
# Iterating through data...
# Benchmark_validation Loss: 0.2317 Acc: 0.9225
#
# Epoch 11/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2207 Acc: 0.9100
# Iterating through data...
# Benchmark_validation Loss: 0.3709 Acc: 0.8592
#
# Epoch 12/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2300 Acc: 0.9159
# Iterating through data...
# Benchmark_validation Loss: 0.2459 Acc: 0.8732
#
# Epoch 13/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2066 Acc: 0.9130
# Iterating through data...
# Benchmark_validation Loss: 0.2183 Acc: 0.9085
#
# Epoch 14/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2057 Acc: 0.9189
# Iterating through data...
# Benchmark_validation Loss: 0.2973 Acc: 0.8592
#
# Epoch 15/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2234 Acc: 0.9159
# Iterating through data...
# Benchmark_validation Loss: 0.3472 Acc: 0.8451
#
# Epoch 16/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2029 Acc: 0.9292
# Iterating through data...
# Benchmark_validation Loss: 0.2961 Acc: 0.8662
#
# Epoch 17/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2065 Acc: 0.9218
# Iterating through data...
# Benchmark_validation Loss: 0.3398 Acc: 0.8592
#
# Epoch 18/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2165 Acc: 0.9263
# Iterating through data...
# Benchmark_validation Loss: 0.3747 Acc: 0.8451
#
# Epoch 19/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2047 Acc: 0.9174
# Iterating through data...
# Benchmark_validation Loss: 0.2748 Acc: 0.8803
#
# Epoch 20/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2128 Acc: 0.9174
# Iterating through data...
# Benchmark_validation Loss: 0.2085 Acc: 0.9155
#
# Epoch 21/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2167 Acc: 0.9174
# Iterating through data...
# Benchmark_validation Loss: 0.3286 Acc: 0.8592
#
# Epoch 22/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2344 Acc: 0.9189
# Iterating through data...
# Benchmark_validation Loss: 0.3452 Acc: 0.8592
#
# Epoch 23/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2253 Acc: 0.9174
# Iterating through data...
# Benchmark_validation Loss: 0.3253 Acc: 0.8592
#
# Epoch 24/24
# ----------
# Iterating through data...
# Benchmark_training Loss: 0.2337 Acc: 0.9145
# Iterating through data...
# Benchmark_validation Loss: 0.2350 Acc: 0.9014
#
# Training complete in 17m 25s
# Best val Acc: 0.922535

# %%
val_loss
# Out:
# [0.3364220561302254,
#  0.4113489153047263,
#  0.4318884165144303,
#  0.27752773372971284,
#  0.3233098151961546,
#  0.377486584701536,
#  0.22373238546055624,
#  0.2964712275769299,
#  0.4901388723691794,
#  0.2627940964950642,
#  0.23172531923425504,
#  0.3709116151300587,
#  0.2458758387258801,
#  0.2183495757734062,
#  0.2973192202150297,
#  0.347160185182231,
#  0.29610585841074794,
#  0.33977135160649324,
#  0.37472982799739274,
#  0.27476733722920776,
#  0.20846719888340629,
#  0.3285822695593389,
#  0.3451565682402694,
#  0.3252577624270614,
#  0.23500661945468942]

# %%
tacc = torch.stack(train_acc)
tacc = tacc.cpu().detach().numpy()
vacc = torch.stack(val_acc)
vacc = vacc.cpu().detach().numpy()

# trainloss = torch.stack(train_loss)
# trainloss = trainloss.cpu().detach().numpy()
# valloss = torch.stack(val_loss)
# valloss = valloss.cpu().detach().numpy()

# %%
# loss plot
fig = plt.figure(figsize=(10,7))
plt.title("Train-Validation Accuracy")
plt.plot(tacc, label='train')
plt.plot(vacc, label='validation')
plt.xlabel('num_epochs', fontsize=12)
plt.ylabel('accuracy', fontsize=12)
plt.legend(loc='best')

# %%
# accuracy plot
fig = plt.figure(figsize=(10,7))
plt.title("Train-Validation Accuracy")
plt.plot(tacc, label='train')
plt.plot(vacc, label='validation')
plt.xlabel('num_epochs', fontsize=12)
plt.ylabel('accuracy', fontsize=12)
plt.legend(loc='best')

# %% [markdown]
# use the test dataset to see the performance

# %%
predlist = torch.zeros(0, dtype=torch.long, device='cpu')
lbllist = torch.zeros(0, dtype=torch.long, device = 'cpu')

with torch.no_grad():
  for inputs, classes in dataloaders['Benchmark_validation']:
    inputs = inputs.to(device)
    classes = classes.to(device)
    outputs = base_model(inputs)
    _, preds = torch.max(outputs, 1)

    predlist=torch.cat([predlist, preds.view(-1).cpu()])
    lbllist=torch.cat([lbllist, classes.view(-1).cpu()])

  preds = predlist.numpy()
  labels = lbllist.numpy()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
conf_mat = confusion_matrix(labels, preds)
fig, ax = plt.subplots(figsize = (8,8))
sns.heatmap(conf_mat, annot = True, fmt = 'd')
plt.ylabel('Actual')
plt.xlabel('pred')
plt.show()

# %%
cm=confusion_matrix(labels,preds)
print(cm)
# Out:
# [[45  0]
#  [11 86]]

# %%
from sklearn.metrics import classification_report
matrix = classification_report(labels,preds,target_names=class_names)
print('Classification report : \n',matrix)
# Out:
# Classification report :
#                 precision    recall  f1-score   support
#
# Non_Violation       0.80      1.00      0.89        45
#     Violation       1.00      0.89      0.94        97
#
#      accuracy                           0.92       142
#     macro avg       0.90      0.94      0.92       142
#  weighted avg       0.94      0.92      0.92       142
